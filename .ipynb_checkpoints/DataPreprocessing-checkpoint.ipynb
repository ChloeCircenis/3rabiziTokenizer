# %%
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-1.0.0-py3-none-any.whl.metadata (40 kB)
# Collecting kagglesdk<1.0,>=0.1.14 (from kagglehub)
#   Downloading kagglesdk-0.1.16-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from kagglehub) (24.1)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from kagglehub) (4.66.5)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.11/site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (5.28.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->kagglehub) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->kagglehub) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->kagglehub) (2025.1.31)
# Downloading kagglehub-1.0.0-py3-none-any.whl (70 kB)
# Downloading kagglesdk-0.1.16-py3-none-any.whl (160 kB)
# Installing collected packages: kagglesdk, kagglehub
# Successfully installed kagglehub-1.0.0 kagglesdk-0.1.16
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("samawel97/arabizi-dialect")

print("Path to dataset files:", path)
# Out:
# Downloading to /home/jovyan/.cache/kagglehub/datasets/samawel97/arabizi-dialect/1.archive...
# 100%|██████████| 3.62M/3.62M [00:00<00:00, 45.4MB/s]
# Extracting files...
# Path to dataset files: /home/jovyan/.cache/kagglehub/datasets/samawel97/arabizi-dialect/versions/1

# %%
for dirname, _, filenames in os.walk(path):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /home/jovyan/.cache/kagglehub/datasets/samawel97/arabizi-dialect/versions/1/SampleSubmission (32).csv
# /home/jovyan/.cache/kagglehub/datasets/samawel97/arabizi-dialect/versions/1/Train (1).csv
# /home/jovyan/.cache/kagglehub/datasets/samawel97/arabizi-dialect/versions/1/Test (1).csv

# %%
test = path+'/versions/1/Test (1).csv'
train =
